# %% [markdown]
# # Part A: Load and Inspect the Dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# If your notebook is inside the notebooks/ folder, use:
df = pd.read_csv("../data/processed/olist_orders_abt.csv")
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  fdbacfcb1abbad615c18b561769e63be  767bbd1d4db1520ac11ed952a4e74e38
# 1  9e5295f8466d100413a12a9eecc997ac  be820823ef442673fa0ed3e53f21f972
# 2  5b3bc2713bf114be5c3717dbe29a65d8  ad3785c59be452a6b68362ceffb899dd
# 3  d194109b097dc0d115fe754575607ce0  55b37bc48fa73478224ed9c47ffb3a1e
# 4  5a774aca6d358279e86bf92d70b696f3  716b7a2f1429aa24c93f5a3c4831cc70
#
#                  customer_unique_id   customer_city customer_state  \
# 0  9399eb648f9a5a11a2e27e88e67bbfbb        brasilia             PE
# 1  adb2a7250805dc8f2e8b6fc6a73ed91c      uberlandia             MG
# 2  8b8889e0686683ce1cc654e5fa8bdf9e  ribeirao preto             SP
# 3  9f359d3286c8c8662cdce622bccbd088  ribeirao preto             SP
# 4  9fdd5437fce8c4f168b575db334eaa3d          osasco             SP
#
#   order_status  order_year  order_month  order_day  order_day_of_week  ...  \
# 0    delivered        2016           12         30                  4  ...
# 1    delivered        2017            3          2                  3  ...
# 2    delivered        2017           12          8                  4  ...
# 3    delivered        2018            4          5                  3  ...
# 4    delivered        2018            2          4                  6  ...
#
#    total_payment_value  max_payment_installments  payment_types_count  \
# 0               216.15                         1                    1
# 1               200.58                         2                    1
# 2                55.12                         3                    1
# 3               508.15                        12                    2
# 4               124.69                         1                    1
#
#    dominant_payment_type  total_items  total_price  total_freight  \
# 0                 boleto            1        37.10          32.56
# 1            credit_card            1        82.51          13.54
# 2            credit_card            1        30.33          15.42
# 3                 boleto            2       136.67          67.61
# 4            credit_card            2        68.14          52.84
#
#    unique_products  unique_sellers  main_product_category
# 0                1               1         bed_bath_table
# 1                1               1    luggage_accessories
# 2                1               1        books_technical
# 3                2               2        books_technical
# 4                2               2              telephony
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (99441, 29)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  99441 non-null  str
#  1   customer_id               99441 non-null  str
#  2   customer_unique_id        99441 non-null  str
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
#  5   order_status              99441 non-null  str
#  6   order_year                99441 non-null  int64
#  7   order_month               99441 non-null  int64
#  8   order_day                 99441 non-null  int64
#  9   order_day_of_week         99441 non-null  int64
#  10  order_hour                99441 non-null  int64
#  11  delivery_days             96107 non-null  float64
#  12  estimated_delivery_days   99441 non-null  int64
#  13  delivery_delay_days       96107 non-null  float64
#  14  is_late_delivery          99441 non-null  int64
#  15  review_score              79588 non-null  float64
#  16  is_low_review             99441 non-null  int64
#  17  review_comment_count      79588 non-null  float64
#  18  has_review_comment        79588 non-null  float64
#  19  total_payment_value       99441 non-null  float64
#  20  max_payment_installments  99441 non-null  int64
#  21  payment_types_count       99441 non-null  int64
#  22  dominant_payment_type     99441 non-null  str
#  23  total_items               99441 non-null  int64
#  24  total_price               99441 non-null  float64
#  25  total_freight             99441 non-null  float64
#  26  unique_products           99441 non-null  int64
#  27  unique_sellers            99441 non-null  int64
#  28  main_product_category     97356 non-null  str
# dtypes: float64(8), int64(13), str(8)
# memory usage: 22.0 MB

# %%
df.describe()
# Out:
#          order_year   order_month     order_day  order_day_of_week  \
# count  99441.000000  99441.000000  99441.000000       99441.000000
# mean    2017.217948      6.683521     15.613731           2.998914
# std        0.692052      3.408099      8.756573           2.003060
# min     2016.000000      1.000000      1.000000           0.000000
# 25%     2017.000000      4.000000      8.000000           1.000000
# 50%     2017.000000      7.000000     15.000000           3.000000
# 75%     2018.000000     10.000000     23.000000           5.000000
# max     2018.000000     12.000000     31.000000           6.000000
#
#          order_hour  delivery_days  estimated_delivery_days  \
# count  99441.000000   96107.000000             99441.000000
# mean      11.535393      11.739665                29.990497
# std        6.910660       5.822629                 8.957821
# min        0.000000       1.000000                15.000000
# 25%        6.000000       7.000000                22.000000
# 50%       12.000000      12.000000                30.000000
# 75%       18.000000      17.000000                38.000000
# max       23.000000      23.000000                45.000000
#
#        delivery_delay_days  is_late_delivery  review_score  ...  \
# count         96107.000000      99441.000000  79588.000000  ...
# mean            -18.252916          0.035629      4.116915  ...
# std              10.679455          0.185365      1.329365  ...
# min             -44.000000          0.000000      1.000000  ...
# 25%             -26.000000          0.000000      4.000000  ...
# 50%             -18.000000          0.000000      5.000000  ...
# 75%             -10.000000          0.000000      5.000000  ...
# max               8.000000          1.000000      5.000000  ...
#
#        review_comment_count  has_review_comment  total_payment_value  \
# count          79588.000000        79588.000000         99441.000000
# mean               0.749786            0.749786           153.981821
# std                0.433139            0.433139           168.211203
# min                0.000000            0.000000             1.880000
# 25%                0.000000            0.000000            53.530000
# 50%                1.000000            1.000000           101.790000
# 75%                1.000000            1.000000           191.910000
# max                1.000000            1.000000          4289.600000
#
#        max_payment_installments  payment_types_count   total_items  \
# count              99441.000000         99441.000000  99441.000000
# mean                   3.561961             1.056013      1.488139
# std                    3.665184             0.235522      0.897470
# min                    1.000000             1.000000      1.000000
# 25%                    1.000000             1.000000      1.000000
# 50%                    2.000000             1.000000      1.000000
# 75%                    6.000000             1.000000      2.000000
# max                   12.000000             3.000000      5.000000
#
#         total_price  total_freight  unique_products  unique_sellers
# count  99441.000000   99441.000000     99441.000000    99441.000000
# mean     111.430165      40.948512         1.488109        1.487928
# std      109.516986      29.326879         0.897403        0.897098
# min        2.110000       5.000000         1.000000        1.000000
# 25%       40.080000      20.760000         1.000000        1.000000
# 50%       75.940000      35.220000         1.000000        1.000000
# 75%      143.860000      48.590000         2.000000        2.000000
# max     2193.780000     223.190000         5.000000        5.000000
#
# [8 rows x 21 columns]

# %%
# Student Task 1: Create Data Type Lists
nominal_columns = [
    "customer_state",
    "customer_city",
    "main_product_category",
    "dominant_payment_type",
    "order_status"
]

ordinal_columns = [
    "review_score"
]

interval_columns = [
    "order_hour",
    "order_month",
    "order_day_of_week"
]

ratio_columns = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "estimated_delivery_days",
    "delivery_delay_days",
    "total_items",
    "unique_products",
    "unique_sellers"
]

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'customer_unique_id', 'customer_city',
#        'customer_state', 'order_status', 'order_year', 'order_month',
#        'order_day', 'order_day_of_week', 'order_hour', 'delivery_days',
#        'estimated_delivery_days', 'delivery_delay_days', 'is_late_delivery',
#        'review_score', 'is_low_review', 'review_comment_count',
#        'has_review_comment', 'total_payment_value', 'max_payment_installments',
#        'payment_types_count', 'dominant_payment_type', 'total_items',
#        'total_price', 'total_freight', 'unique_products', 'unique_sellers',
#        'main_product_category'],
#       dtype='str')

# %%
def keep_existing_columns(dataframe, columns):
    return [col for col in columns if col in dataframe.columns]

nominal_columns = keep_existing_columns(df, nominal_columns)
ordinal_columns = keep_existing_columns(df, ordinal_columns)
interval_columns = keep_existing_columns(df, interval_columns)
ratio_columns = keep_existing_columns(df, ratio_columns)

# %% [markdown]
# # Part C: Create Additional Teaching-Friendly Features

# %%
if "delivery_days" in df.columns:
    df["delivery_speed_category"] = pd.cut(
        df["delivery_days"],
        bins=[-1, 7, 15, 30, np.inf],
        labels=["Fast", "Normal", "Slow", "Very Delayed"]
    )

# %%
if "total_payment_value" in df.columns:
    df["payment_value_band"] = pd.qcut(
        df["total_payment_value"],
        q=4,
        labels=["Low", "Medium", "High", "Premium"],
        duplicates="drop"
    )

# %% [markdown]
# # Part D: Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# order_id                        0
# customer_id                     0
# customer_unique_id              0
# customer_city                   0
# customer_state                  0
# order_status                    0
# order_year                      0
# order_month                     0
# order_day                       0
# order_day_of_week               0
# order_hour                      0
# delivery_days                3334
# estimated_delivery_days         0
# delivery_delay_days          3334
# is_late_delivery                0
# review_score                19853
# is_low_review                   0
# review_comment_count        19853
# has_review_comment          19853
# total_payment_value             0
# max_payment_installments        0
# payment_types_count             0
# dominant_payment_type           0
# total_items                     0
# total_price                     0
# total_freight                   0
# unique_products                 0
# unique_sellers                  0
# main_product_category        2085
# delivery_speed_category      3334
# payment_value_band              0
# dtype: int64

# %%
missing_summary = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percent": (df.isnull().sum() / len(df)) * 100
}).sort_values(by="missing_percent", ascending=False)

missing_summary.head(20)
# Out:
#                          missing_count  missing_percent
# has_review_comment               19853        19.964602
# review_comment_count             19853        19.964602
# review_score                     19853        19.964602
# delivery_speed_category           3334         3.352742
# delivery_delay_days               3334         3.352742
# delivery_days                     3334         3.352742
# main_product_category             2085         2.096721
# order_year                           0         0.000000
# order_status                         0         0.000000
# order_month                          0         0.000000
# order_id                             0         0.000000
# customer_city                        0         0.000000
# customer_state                       0         0.000000
# customer_id                          0         0.000000
# customer_unique_id                   0         0.000000
# is_late_delivery                     0         0.000000
# estimated_delivery_days              0         0.000000
# order_day_of_week                    0         0.000000
# order_hour                           0         0.000000
# order_day                            0         0.000000

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

sns.barplot(
    x=missing_values.values,
    y=missing_values.index
)

plt.title("Missing Values by Column")
plt.xlabel("Number of Missing Values")
plt.ylabel("Column")
plt.show()

# %%
sns.heatmap(
    df.isnull(),
    cbar=False
)

plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %% [markdown]
# # Part E: Univariate Analysis

# %%
if "customer_state" in df.columns:
    sns.countplot(
        data=df,
        x="customer_state",
        order=df["customer_state"].value_counts().index
    )
    plt.title("Orders by Customer State")
    plt.xlabel("Customer State")
    plt.ylabel("Number of Orders")
    plt.xticks(rotation=45)
    plt.show()

# %%
if "main_product_category" in df.columns:
    top_categories = df["main_product_category"].value_counts().head(15).index
    
    sns.countplot(
        data=df[df["main_product_category"].isin(top_categories)],
        y="main_product_category",
        order=top_categories
    )
    
    plt.title("Top Product Categories")
    plt.xlabel("Number of Orders")
    plt.ylabel("Product Category")
    plt.show()

# %%
if "delivery_speed_category" in df.columns:
    delivery_order = ["Fast", "Normal", "Slow", "Very Delayed"]
    
    sns.countplot(
        data=df,
        x="delivery_speed_category",
        order=delivery_order
    )
    
    plt.title("Delivery Speed Category Distribution")
    plt.xlabel("Delivery Speed Category")
    plt.ylabel("Number of Orders")
    plt.show()

# %%
if "total_payment_value" in df.columns:
    sns.histplot(
        data=df,
        x="total_payment_value",
        bins=50,
        kde=True
    )
    
    plt.title("Distribution of Total Payment Value")
    plt.xlabel("Total Payment Value")
    plt.ylabel("Frequency")
    plt.show()

# %%
if "delivery_days" in df.columns:
    sns.histplot(
        data=df,
        x="delivery_days",
        bins=40,
        kde=True
    )
    
    plt.title("Distribution of Delivery Days")
    plt.xlabel("Delivery Days")
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# # Part F: Skewness

# %%
skew_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "delivery_delay_days",
    "total_items"
]

# %%
skew_cols = keep_existing_columns(df, skew_cols)

skewness_values = df[skew_cols].skew().sort_values(ascending=False)

skewness_values
# Out:
# total_payment_value    3.921623
# total_price            2.691880
# total_items            2.094459
# total_freight          1.686955
# delivery_days         -0.005317
# delivery_delay_days   -0.006125
# dtype: float64

# %%
sns.barplot(
    x=skewness_values.values,
    y=skewness_values.index
)

plt.title("Skewness of Numerical Features")
plt.xlabel("Skewness")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# # Part G: Box Plot and Outlier Detection

# %%
if "total_payment_value" in df.columns:
    sns.boxplot(
        data=df,
        y="total_payment_value"
    )
    
    plt.title("Box Plot of Total Payment Value")
    plt.ylabel("Total Payment Value")
    plt.show()

# %%
if "delivery_days" in df.columns:
    sns.boxplot(
        data=df,
        y="delivery_days"
    )
    
    plt.title("Box Plot of Delivery Days")
    plt.ylabel("Delivery Days")
    plt.show()

# %%
def iqr_outlier_summary(dataframe, column):
    q1 = dataframe[column].quantile(0.25)
    q3 = dataframe[column].quantile(0.75)
    iqr = q3 - q1
    
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    outliers = dataframe[
        (dataframe[column] < lower_bound) |
        (dataframe[column] > upper_bound)
    ]
    
    summary = {
        "column": column,
        "q1": q1,
        "q3": q3,
        "iqr": iqr,
        "lower_bound": lower_bound,
        "upper_bound": upper_bound,
        "outlier_count": len(outliers),
        "outlier_percent": (len(outliers) / len(dataframe)) * 100
    }
    
    return summary

# %%
if "total_payment_value" in df.columns:
    print(iqr_outlier_summary(df, "total_payment_value"))
# Out:
# {'column': 'total_payment_value', 'q1': np.float64(53.53), 'q3': np.float64(191.91), 'iqr': np.float64(138.38), 'lower_bound': np.float64(-154.04), 'upper_bound': np.float64(399.48), 'outlier_count': 6890, 'outlier_percent': 6.928731609698213}

# %%
if "delivery_days" in df.columns:
    print(iqr_outlier_summary(df, "delivery_days"))
# Out:
# {'column': 'delivery_days', 'q1': np.float64(7.0), 'q3': np.float64(17.0), 'iqr': np.float64(10.0), 'lower_bound': np.float64(-8.0), 'upper_bound': np.float64(32.0), 'outlier_count': 0, 'outlier_percent': 0.0}

# %% [markdown]
# # Part H: Multivariate Analysis

# %%
if {"delivery_delay_days", "review_score"}.issubset(df.columns):
    sns.scatterplot(
        data=df,
        x="delivery_delay_days",
        y="review_score",
        alpha=0.6
    )
    
    plt.title("Delivery Delay Days vs Review Score")
    plt.xlabel("Delivery Delay Days")
    plt.ylabel("Review Score")
    plt.show()

# %%
if {"total_payment_value", "total_freight", "is_late_delivery"}.issubset(df.columns):
    sns.scatterplot(
        data=df,
        x="total_payment_value",
        y="total_freight",
        hue="is_late_delivery",
        alpha=0.7
    )
    
    plt.title("Payment Value vs Freight by Late Delivery")
    plt.xlabel("Total Payment Value")
    plt.ylabel("Total Freight")
    plt.show()

# %%
if {"is_late_delivery", "review_score"}.issubset(df.columns):
    sns.boxplot(
        data=df,
        x="is_late_delivery",
        y="review_score"
    )
    
    plt.title("Review Score by Late Delivery Status")
    plt.xlabel("Is Late Delivery")
    plt.ylabel("Review Score")
    plt.show()

# %%
numeric_columns = [
    "order_hour",
    "order_month",
    "order_day_of_week",
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "estimated_delivery_days",
    "delivery_delay_days",
    "total_items",
    "unique_products",
    "unique_sellers",
    "review_score",
    "review_comment_count",
    "has_review_comment",
    "is_late_delivery",
    "is_low_review"
]

numeric_columns = keep_existing_columns(df, numeric_columns)

corr = df[numeric_columns].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Part I: Target Variable Analysis

# %%
if "is_late_delivery" in df.columns:
    sns.countplot(
        data=df,
        x="is_late_delivery"
    )
    
    plt.title("Target Distribution: Late Delivery")
    plt.xlabel("Is Late Delivery")
    plt.ylabel("Number of Orders")
    plt.show()

# %%
if "is_low_review" in df.columns:
    sns.countplot(
        data=df,
        x="is_low_review"
    )
    
    plt.title("Target Distribution: Low Review")
    plt.xlabel("Is Low Review")
    plt.ylabel("Number of Orders")
    plt.show()

# %% [markdown]
# # Part J: Fixing Data Problems

# %%
clean_df = df.copy()

# %%
if "delivery_days" in clean_df.columns:
    clean_df["missing_delivery_days"] = clean_df["delivery_days"].isnull().astype(int)

# %%
categorical_missing_cols = [
    "main_product_category",
    "dominant_payment_type",
    "delivery_speed_category",
    "payment_value_band",
    "customer_state",
    "customer_city",
    "order_status"
]

categorical_missing_cols = keep_existing_columns(clean_df, categorical_missing_cols)

for col in categorical_missing_cols:
    if clean_df[col].dtype.name == 'category':
        if "Unknown" not in clean_df[col].cat.categories:
            clean_df[col] = clean_df[col].cat.add_categories("Unknown")
    clean_df[col] = clean_df[col].fillna("Unknown")

# %%
numerical_missing_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "estimated_delivery_days",
    "delivery_delay_days",
    "review_score",
    "total_items",
    "unique_products",
    "unique_sellers"
]

numerical_missing_cols = keep_existing_columns(clean_df, numerical_missing_cols)

for col in numerical_missing_cols:
    clean_df[col] = clean_df[col].fillna(clean_df[col].median())

# %%
if "total_payment_value" in clean_df.columns:
    clean_df["log_total_payment_value"] = np.log1p(clean_df["total_payment_value"])

if "total_freight" in clean_df.columns:
    clean_df["log_total_freight"] = np.log1p(clean_df["total_freight"])

if "total_price" in clean_df.columns:
    clean_df["log_total_price"] = np.log1p(clean_df["total_price"])

# %%
if {"total_payment_value", "log_total_payment_value"}.issubset(clean_df.columns):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    sns.histplot(
        data=clean_df,
        x="total_payment_value",
        bins=50,
        kde=True,
        ax=axes[0]
    )
    axes[0].set_title("Original Total Payment Value")
    
    sns.histplot(
        data=clean_df,
        x="log_total_payment_value",
        bins=50,
        kde=True,
        ax=axes[1]
    )
    axes[1].set_title("Log-Transformed Total Payment Value")
    
    plt.show()

# %% [markdown]
# # Part K: Scaling Demonstration

# %%
scale_check_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "total_items"
]

scale_check_cols = keep_existing_columns(clean_df, scale_check_cols)

clean_df[scale_check_cols].describe()
# Out:
#        total_payment_value   total_price  total_freight  delivery_days  \
# count         99441.000000  99441.000000   99441.000000   99441.000000
# mean            153.981821    111.430165      40.948512      11.748394
# std             168.211203    109.516986      29.326879       5.724379
# min               1.880000      2.110000       5.000000       1.000000
# 25%              53.530000     40.080000      20.760000       7.000000
# 50%             101.790000     75.940000      35.220000      12.000000
# 75%             191.910000    143.860000      48.590000      17.000000
# max            4289.600000   2193.780000     223.190000      23.000000
#
#         total_items
# count  99441.000000
# mean       1.488139
# std        0.897470
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

scaling_cols = [
    "total_payment_value",
    "total_price",
    "total_freight",
    "delivery_days",
    "total_items"
]

scaling_cols = keep_existing_columns(clean_df, scaling_cols)

standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
robust_scaler = RobustScaler()

standard_scaled = standard_scaler.fit_transform(clean_df[scaling_cols])
minmax_scaled = minmax_scaler.fit_transform(clean_df[scaling_cols])
robust_scaled = robust_scaler.fit_transform(clean_df[scaling_cols])

standard_scaled_df = pd.DataFrame(
    standard_scaled,
    columns=[col + "_standard_scaled" for col in scaling_cols]
)

minmax_scaled_df = pd.DataFrame(
    minmax_scaled,
    columns=[col + "_minmax_scaled" for col in scaling_cols]
)

robust_scaled_df = pd.DataFrame(
    robust_scaled,
    columns=[col + "_robust_scaled" for col in scaling_cols]
)

standard_scaled_df.head()
# Out:
#    total_payment_value_standard_scaled  total_price_standard_scaled  \
# 0                             0.369586                    -0.678712
# 1                             0.277023                    -0.264071
# 2                            -0.587727                    -0.740530
# 3                             2.105508                     0.230466
# 4                            -0.174138                    -0.395285
#
#    total_freight_standard_scaled  delivery_days_standard_scaled  \
# 0                      -0.286036                      -1.528277
# 1                      -0.934591                      -0.829508
# 2                      -0.870486                       0.043954
# 3                       0.909119                       0.393338
# 4                       0.405483                       0.742723
#
#    total_items_standard_scaled
# 0                    -0.543908
# 1                    -0.543908
# 2                    -0.543908
# 3                     0.570341
# 4                     0.570341

# %% [markdown]
# # Part L: Data Leakage Discussion
#
# Leakage Example
# Suppose our target is:
# `is_late_delivery`
#
# This target is created from:
# `delivery_delay_days`
#
# If we use `delivery_delay_days` to predict `is_late_delivery`, the model is cheating.

# %%
leakage_columns = [
    "delivery_delay_days",
    "delivery_speed_category"
]

# %% [markdown]
# # Part M: Save Cleaned ABT

# %%
clean_df.to_csv("../data/processed/olist_orders_abt_cleaned.csv", index=False)

print("Cleaned ABT saved successfully.")
print(clean_df.shape)
# Out:
# Cleaned ABT saved successfully.
# (99441, 35)
